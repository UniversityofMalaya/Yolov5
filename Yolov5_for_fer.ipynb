# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v6.1-353-g2e10909 Python-3.7.13 torch-1.12.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (4 CPUs, 25.5 GB RAM, 38.7/166.8 GB disk)

# %%
# !unzip "/content/drive/MyDrive/FER/FER.zip" -d "/content/"

# %%
pwd
# Out:
# '/content/yolov5'

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-0ef91eee-e476-48a2-8be6-800ab1ea2828" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0ef91eee-e476-48a2-8be6-800ab1ea2828">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving FER.yaml to FER.yaml
# User uploaded file "FER.yaml" with length 668 bytes

# %%
ls
# Out:
# CONTRIBUTING.md  export.py   LICENSE    requirements.txt  tutorial.ipynb
# data/            FER.yaml    models/    setup.cfg         utils/
# detect.py        hubconf.py  README.md  train.py          val.py

# %%
# !python train.py --img 640 --batch 64 --epochs 100 --data FER.yaml
# Out:
# train: weights=yolov5s.pt, cfg=, data=FER.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=64, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-353-g2e10909 Python-3.7.13 torch-1.12.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !rm "/content/yolov5/data/images/bus.jpg" "/content/yolov5/data/images/zidane.jpg"

# %%
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-9382ab5a-8afe-4509-bd14-c93f521a8a3b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9382ab5a-8afe-4509-bd14-c93f521a8a3b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Screenshot from 2022-07-13 21-59-18.png to Screenshot from 2022-07-13 21-59-18.png
# User uploaded file "Screenshot from 2022-07-13 21-59-18.png" with length 648452 bytes

# %%
# !mv "/content/yolov5/Screenshot from 2022-07-13 21-59-18.png" "/content/yolov5/data/images/"

# %%
# !python detect.py --weights "/content/yolov5/runs/train/exp/weights/last.pt" --img 640 --conf 0.25 --source data/images
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/last.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-353-g2e10909 Python-3.7.13 torch-1.12.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# image 1/2 /content/yolov5/data/images/Screenshot from 2022-07-13 21-59-18.png: 480x640 1 neutral, 1 sad, 1 happy, Done. (0.012s)
# image 2/2 /content/yolov5/data/images/Screenshot from 2022-08-02 17-13-05.png: 640x512 1 neutral, Done. (0.012s)
# Speed: 0.5ms pre-process, 11.9ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# ...

# %%
fn
# Out:
# 'Screenshot from 2022-08-02 17-13-05.png'

# %%
display.Image(filename=f'runs/detect/exp3/{fn}', width=600)

# %%
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-b8555dc6-52bd-47c8-8c05-c899f92b8707" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b8555dc6-52bd-47c8-8c05-c899f92b8707">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving images.jpeg to images.jpeg
# User uploaded file "images.jpeg" with length 136568 bytes

# %%
# !mv "/content/yolov5/images.jpeg" "/content/yolov5/data/images/"

# %%
# !python detect.py --weights "/content/yolov5/runs/train/exp/weights/last.pt" --img 640 --conf 0.25 --source data/images
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/last.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-353-g2e10909 Python-3.7.13 torch-1.12.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# image 1/4 /content/yolov5/data/images/Screenshot from 2022-07-13 21-59-18.png: 480x640 1 neutral, 1 sad, 1 happy, Done. (0.012s)
# image 2/4 /content/yolov5/data/images/Screenshot from 2022-08-02 17-13-05.png: 640x512 1 neutral, Done. (0.012s)
# image 3/4 /content/yolov5/data/images/images.jpeg: 384x640 1 sad, Done. (0.012s)
# ...

# %%
display.Image(filename=f'runs/detect/exp6/{fn}', width=600)

# %%
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-e3a7eef3-f4f2-40f4-a046-03634c83cb17" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e3a7eef3-f4f2-40f4-a046-03634c83cb17">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 7103263291191020846.mp4 to 7103263291191020846.mp4
# User uploaded file "7103263291191020846.mp4" with length 3812305 bytes

# %%
# !mv "7103617114715655470.mp4" "videos/7103263291191020846.mp4"
# Out:
# mv: cannot stat '7103617114715655470.mp4': No such file or directory

# %%
# !python detect.py --weights "/content/yolov5/runs/train/exp/weights/last.pt" --img 640 --conf 0.25 --source videos/

# %%
url = f"/runs/detect/exp8/{fn}"
# then display it
from IPython.display import HTML
HTML(f"""<video src={url} width=500 controls/>""")
# Out:
# <video src=/runs/detect/exp8/7103263291191020846.mp4 width=500 controls/>
